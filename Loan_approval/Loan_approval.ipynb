# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train = df_train.drop('id',axis = 1)
df_test = df_test.drop('id',axis = 1)

# %%
df_train.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          37          35000                  RENT                0.0
# 1          22          56000                   OWN                6.0
# 2          29          28800                   OWN                8.0
# 3          30          70000                  RENT               14.0
# 4          22          60000                  RENT                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0   EDUCATION          B       6000          11.49                 0.17
# 1     MEDICAL          C       4000          13.35                 0.07
# 2    PERSONAL          A       6000           8.90                 0.21
# 3     VENTURE          B      12000          11.11                 0.17
# 4     MEDICAL          A       6000           6.92                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# 0                         N                          14            0
# 1                         N                           2            0
# 2                         N                          10            0
# 3                         N                           5            0
# 4                         N                           3            0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  58645 non-null  int64
#  1   person_income               58645 non-null  int64
#  2   person_home_ownership       58645 non-null  object
#  3   person_emp_length           58645 non-null  float64
#  4   loan_intent                 58645 non-null  object
#  5   loan_grade                  58645 non-null  object
#  6   loan_amnt                   58645 non-null  int64
#  7   loan_int_rate               58645 non-null  float64
#  8   loan_percent_income         58645 non-null  float64
#  9   cb_person_default_on_file   58645 non-null  object
#  10  cb_person_cred_hist_length  58645 non-null  int64
#  11  loan_status                 58645 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 5.4+ MB

# %%
df_train.isna().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %%
label = LabelEncoder()

# %%
df_train['person_home_ownership'] = label.fit_transform(df_train['person_home_ownership'])
df_test['person_home_ownership'] = label.transform(df_test['person_home_ownership'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  58645 non-null  int64
#  1   person_income               58645 non-null  int64
#  2   person_home_ownership       58645 non-null  int64
#  3   person_emp_length           58645 non-null  float64
#  4   loan_intent                 58645 non-null  object
#  5   loan_grade                  58645 non-null  object
#  6   loan_amnt                   58645 non-null  int64
#  7   loan_int_rate               58645 non-null  float64
#  8   loan_percent_income         58645 non-null  float64
#  9   cb_person_default_on_file   58645 non-null  object
#  10  cb_person_cred_hist_length  58645 non-null  int64
#  11  loan_status                 58645 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 5.4+ MB

# %%
df_train['loan_grade'] = label.fit_transform(df_train['loan_grade'])
df_test['loan_grade'] = label.transform(df_test['loan_grade'])

# %%
df_train['loan_intent'] = label.fit_transform(df_train['loan_intent'])
df_test['loan_intent'] = label.transform(df_test['loan_intent'])

# %%
df_train['cb_person_default_on_file'] = label.fit_transform(df_train['cb_person_default_on_file'])
df_test['cb_person_default_on_file'] = label.transform(df_test['cb_person_default_on_file'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  58645 non-null  int64
#  1   person_income               58645 non-null  int64
#  2   person_home_ownership       58645 non-null  int64
#  3   person_emp_length           58645 non-null  float64
#  4   loan_intent                 58645 non-null  int64
#  5   loan_grade                  58645 non-null  int64
#  6   loan_amnt                   58645 non-null  int64
#  7   loan_int_rate               58645 non-null  float64
#  8   loan_percent_income         58645 non-null  float64
#  9   cb_person_default_on_file   58645 non-null  int64
#  10  cb_person_cred_hist_length  58645 non-null  int64
#  11  loan_status                 58645 non-null  int64
# dtypes: float64(3), int64(9)
# memory usage: 5.4 MB

# %%
X_train = df_train.drop('loan_status', axis = 1)
y_train = df_train['loan_status']
x_test = df_test.copy()

# %%
model = RandomForestClassifier()

# %%
model_params = {
    'n_estimators':[60,70,80,90],
    'criterion':['gini','entropy','log_loss'],
    'max_depth':[None,1,3,5,7],
    'max_features':[None,'sqrt','log2']
}

# %%
final_model = GridSearchCV(model,param_grid = model_params, cv = 3, verbose = 2)

# %%
final_model.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=60; total time=  10.1s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=60; total time=  10.3s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=60; total time=   9.7s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=70; total time=  11.1s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=70; total time=  11.5s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=70; total time=  11.2s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=80; total time=  12.5s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=80; total time=  13.4s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=80; total time=  13.3s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=90; total time=  14.7s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=90; total time=  15.5s
# [CV] END criterion=gini, max_depth=None, max_features=None, n_estimators=90; total time=  15.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.4s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=70; total time=   4.1s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=70; total time=   3.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=70; total time=   4.0s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.6s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=90; total time=   4.8s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=90; total time=   5.2s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=90; total time=   5.2s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=60; total time=   3.6s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=60; total time=   3.4s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=60; total time=   3.4s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=70; total time=   3.9s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=70; total time=   3.9s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=70; total time=   4.0s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=80; total time=   4.3s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=80; total time=   4.5s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=80; total time=   4.6s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=90; total time=   5.1s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=90; total time=   5.1s
# [CV] END criterion=gini, max_depth=None, max_features=log2, n_estimators=90; total time=   5.2s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=60; total time=   0.9s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=70; total time=   0.9s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=70; total time=   0.9s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=70; total time=   1.0s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=80; total time=   1.1s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=80; total time=   1.1s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=80; total time=   1.2s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=90; total time=   1.3s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=90; total time=   1.3s
# [CV] END criterion=gini, max_depth=1, max_features=None, n_estimators=90; total time=   1.3s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.4s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.4s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.4s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=60; total time=   0.4s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=60; total time=   0.4s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=60; total time=   0.5s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=70; total time=   0.5s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=70; total time=   0.4s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=70; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END criterion=gini, max_depth=1, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=60; total time=   2.1s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=60; total time=   2.1s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=60; total time=   2.0s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=70; total time=   2.6s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=70; total time=   2.5s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=70; total time=   2.5s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=80; total time=   2.6s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=80; total time=   2.7s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=80; total time=   2.8s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=90; total time=   3.1s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=90; total time=   3.0s
# [CV] END criterion=gini, max_depth=3, max_features=None, n_estimators=90; total time=   3.1s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=70; total time=   0.9s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=70; total time=   0.9s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=70; total time=   1.0s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.1s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.1s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.1s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.3s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.2s
# [CV] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.2s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=60; total time=   0.8s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=70; total time=   1.0s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=70; total time=   0.9s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=70; total time=   0.9s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=80; total time=   1.1s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=80; total time=   1.2s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=80; total time=   1.1s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=90; total time=   1.3s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=90; total time=   1.3s
# [CV] END criterion=gini, max_depth=3, max_features=log2, n_estimators=90; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=60; total time=   3.3s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=60; total time=   3.4s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=60; total time=   3.3s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=70; total time=   3.8s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=70; total time=   3.8s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=70; total time=   3.8s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=80; total time=   4.3s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=80; total time=   4.3s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=80; total time=   4.5s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=90; total time=   4.9s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=90; total time=   5.1s
# [CV] END criterion=gini, max_depth=5, max_features=None, n_estimators=90; total time=   4.6s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.2s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.6s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.6s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.6s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=90; total time=   2.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=90; total time=   1.8s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=90; total time=   1.8s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=60; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=60; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=60; total time=   1.2s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=70; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=70; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=70; total time=   1.6s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=80; total time=   1.9s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=80; total time=   1.6s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=80; total time=   1.6s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=90; total time=   1.9s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=90; total time=   1.7s
# [CV] END criterion=gini, max_depth=5, max_features=log2, n_estimators=90; total time=   1.9s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=60; total time=   4.4s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=60; total time=   4.5s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=60; total time=   4.5s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=70; total time=   5.0s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=70; total time=   5.1s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=70; total time=   5.6s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=80; total time=   6.0s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=80; total time=   6.0s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=80; total time=   5.9s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=90; total time=   6.7s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=90; total time=   6.6s
# [CV] END criterion=gini, max_depth=7, max_features=None, n_estimators=90; total time=   6.8s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.6s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.6s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.7s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.8s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.8s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.0s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.3s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.1s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.4s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.7s
# [CV] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.5s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=60; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=60; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=60; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=70; total time=   1.8s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=70; total time=   1.7s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=70; total time=   1.9s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=80; total time=   2.1s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=80; total time=   2.1s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=80; total time=   2.3s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=90; total time=   2.3s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=90; total time=   2.5s
# [CV] END criterion=gini, max_depth=7, max_features=log2, n_estimators=90; total time=   2.5s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=60; total time=   9.3s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=60; total time=   9.9s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=60; total time=   9.7s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=70; total time=  11.1s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=70; total time=  11.3s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=70; total time=  11.2s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=80; total time=  12.9s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=80; total time=  12.8s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=80; total time=  12.7s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=90; total time=  13.8s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=90; total time=  14.9s
# [CV] END criterion=entropy, max_depth=None, max_features=None, n_estimators=90; total time=  15.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=70; total time=   3.9s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=70; total time=   4.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=70; total time=   3.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=90; total time=   4.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=90; total time=   4.8s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, n_estimators=90; total time=   4.9s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=60; total time=   3.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=60; total time=   3.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=60; total time=   3.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=70; total time=   3.7s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=70; total time=   3.7s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=70; total time=   3.7s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=80; total time=   4.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=80; total time=   4.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=80; total time=   4.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=90; total time=   4.8s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=90; total time=   5.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, n_estimators=90; total time=   5.2s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=60; total time=   0.9s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=60; total time=   0.9s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=60; total time=   0.8s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=70; total time=   0.9s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=70; total time=   1.1s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=70; total time=   1.0s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=80; total time=   1.2s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=80; total time=   1.2s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=80; total time=   1.2s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=90; total time=   1.4s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=90; total time=   1.4s
# [CV] END criterion=entropy, max_depth=1, max_features=None, n_estimators=90; total time=   1.3s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.4s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.4s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.6s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.7s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.7s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=60; total time=   0.4s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=60; total time=   0.4s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=60; total time=   0.4s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=70; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=70; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=70; total time=   0.5s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=90; total time=   0.9s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=90; total time=   0.7s
# [CV] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=90; total time=   0.7s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=60; total time=   2.0s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=60; total time=   2.1s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=60; total time=   2.1s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=70; total time=   2.5s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=70; total time=   2.4s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=70; total time=   2.4s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=80; total time=   2.9s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=80; total time=   2.8s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=80; total time=   2.8s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=90; total time=   3.2s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=90; total time=   2.9s
# [CV] END criterion=entropy, max_depth=3, max_features=None, n_estimators=90; total time=   3.3s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.8s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.9s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.9s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=70; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=70; total time=   0.9s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=70; total time=   0.9s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.1s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.3s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.2s
# [CV] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.2s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=60; total time=   0.9s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=60; total time=   0.8s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=60; total time=   0.8s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=70; total time=   0.8s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=70; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=70; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=80; total time=   1.2s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=80; total time=   1.2s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=80; total time=   1.1s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=90; total time=   1.3s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=90; total time=   1.3s
# [CV] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=90; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=60; total time=   3.4s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=60; total time=   3.2s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=60; total time=   3.3s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=70; total time=   3.9s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=70; total time=   3.8s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=70; total time=   3.9s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=80; total time=   4.4s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=80; total time=   4.6s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=80; total time=   4.4s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=90; total time=   5.0s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=90; total time=   4.6s
# [CV] END criterion=entropy, max_depth=5, max_features=None, n_estimators=90; total time=   5.3s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.2s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.2s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.7s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.8s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.8s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=90; total time=   1.9s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=90; total time=   2.0s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=90; total time=   1.9s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=60; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=60; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=60; total time=   1.1s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=70; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=70; total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=70; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=80; total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=80; total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=80; total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=90; total time=   2.0s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=90; total time=   1.9s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=90; total time=   2.0s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=60; total time=   4.8s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=60; total time=   4.4s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=60; total time=   4.6s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=70; total time=   5.5s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=70; total time=   5.1s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=70; total time=   5.1s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=80; total time=   6.0s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=80; total time=   5.9s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=80; total time=   6.2s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=90; total time=   6.7s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=90; total time=   7.4s
# [CV] END criterion=entropy, max_depth=7, max_features=None, n_estimators=90; total time=   6.9s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.7s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.6s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.6s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.9s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.9s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.8s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.2s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.3s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.1s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.8s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.5s
# [CV] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.4s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=60; total time=   1.6s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=60; total time=   1.7s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=60; total time=   1.6s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=70; total time=   2.0s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=70; total time=   2.1s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=70; total time=   1.9s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=80; total time=   2.2s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=80; total time=   2.4s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=80; total time=   2.2s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=90; total time=   2.5s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=90; total time=   2.6s
# [CV] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=90; total time=   2.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=60; total time=   9.5s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=60; total time=  10.0s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=60; total time=   9.5s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=70; total time=  10.9s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=70; total time=  11.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=70; total time=  11.1s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=80; total time=  12.5s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=80; total time=  12.7s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=80; total time=  12.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=90; total time=  13.9s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=90; total time=  15.1s
# [CV] END criterion=log_loss, max_depth=None, max_features=None, n_estimators=90; total time=  14.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.3s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=60; total time=   3.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=70; total time=   4.0s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=70; total time=   4.2s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=70; total time=   4.0s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.8s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.7s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=80; total time=   4.5s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=90; total time=   5.2s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=90; total time=   5.2s
# [CV] END criterion=log_loss, max_depth=None, max_features=sqrt, n_estimators=90; total time=   5.0s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=60; total time=   3.3s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=60; total time=   3.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=60; total time=   3.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=70; total time=   4.1s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=70; total time=   4.0s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=70; total time=   4.1s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=80; total time=   4.3s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=80; total time=   4.4s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=80; total time=   4.6s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=90; total time=   4.9s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=90; total time=   5.2s
# [CV] END criterion=log_loss, max_depth=None, max_features=log2, n_estimators=90; total time=   5.3s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=60; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=60; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=60; total time=   0.8s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=70; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=80; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=80; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=80; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=90; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=90; total time=   1.7s
# [CV] END criterion=log_loss, max_depth=1, max_features=None, n_estimators=90; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=60; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=70; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.6s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=80; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=1, max_features=sqrt, n_estimators=90; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=60; total time=   0.3s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=60; total time=   0.4s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=60; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=70; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=70; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=70; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=80; total time=   0.6s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=80; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=80; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=90; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=90; total time=   0.5s
# [CV] END criterion=log_loss, max_depth=1, max_features=log2, n_estimators=90; total time=   0.6s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=60; total time=   1.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=60; total time=   1.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=60; total time=   1.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=70; total time=   2.0s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=70; total time=   2.2s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=70; total time=   2.3s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=80; total time=   2.6s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=80; total time=   2.7s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=80; total time=   2.6s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=90; total time=   3.0s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=90; total time=   2.7s
# [CV] END criterion=log_loss, max_depth=3, max_features=None, n_estimators=90; total time=   2.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.8s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=60; total time=   0.8s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=80; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=3, max_features=sqrt, n_estimators=90; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=60; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=60; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=60; total time=   0.7s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=70; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=80; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=80; total time=   0.9s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=80; total time=   1.0s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=90; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=90; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=3, max_features=log2, n_estimators=90; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=60; total time=   3.0s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=60; total time=   3.0s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=60; total time=   3.1s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=70; total time=   3.6s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=70; total time=   3.4s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=70; total time=   3.6s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=80; total time=   4.0s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=80; total time=   4.2s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=80; total time=   4.0s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=90; total time=   4.6s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=90; total time=   4.6s
# [CV] END criterion=log_loss, max_depth=5, max_features=None, n_estimators=90; total time=   4.8s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=60; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=70; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=80; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=90; total time=   1.7s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=90; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=5, max_features=sqrt, n_estimators=90; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=60; total time=   1.2s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=60; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=60; total time=   1.1s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=70; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=70; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=70; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=80; total time=   1.6s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=80; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=80; total time=   1.4s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=90; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=90; total time=   2.0s
# [CV] END criterion=log_loss, max_depth=5, max_features=log2, n_estimators=90; total time=   1.9s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=60; total time=   4.9s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=60; total time=   4.7s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=60; total time=   4.8s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=70; total time=   5.5s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=70; total time=   5.3s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=70; total time=   5.8s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=80; total time=   6.9s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=80; total time=   6.4s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=80; total time=   6.0s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=90; total time=   6.9s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=90; total time=   6.7s
# [CV] END criterion=log_loss, max_depth=7, max_features=None, n_estimators=90; total time=   6.6s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=60; total time=   1.3s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.7s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=70; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.0s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.1s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=80; total time=   2.0s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.3s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.3s
# [CV] END criterion=log_loss, max_depth=7, max_features=sqrt, n_estimators=90; total time=   2.3s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=60; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=60; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=60; total time=   1.5s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=70; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=70; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=70; total time=   1.8s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=80; total time=   2.2s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=80; total time=   2.0s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=80; total time=   2.1s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=90; total time=   2.4s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=90; total time=   2.3s
# [CV] END criterion=log_loss, max_depth=7, max_features=log2, n_estimators=90; total time=   2.4s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 1, 3, 5, 7],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [60, 70, 80, 90]},
#              verbose=2)

# %%
best_model = final_model.best_estimator_

# %%
y_pred = best_model.predict(x_test)

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission['loan_status'] = y_pred

# %%
submission.to_csv('sub.csv', index=False, index_label=False)
